# %%
# import io
# import zipfile
# import requests
# import frontmatter

# url = 'https://github.com/DataTalksClub/faq/archive/refs/heads/main.zip'
# resp = requests.get(url)


# repository_data = []
# zf = zipfile.ZipFile(io.BytesIO(resp.content))

# for file_info in zf.infolist():
#     filename = file_info.filename.lower()
#     if not (filename.endswith('.md') or filename.endswith('.mdx')):
#         continue
#     with zf.open(file_info) as f_in:
#         content = f_in.read()
#         post = frontmatter.loads(content)
#         data = post.to_dict()
#         data['filename'] = filename
#         repository_data.append(data)

# zf.close()

# print(repository_data[1])

# %%
import io
import zipfile
import requests
import frontmatter

def read_repo_data(repo_owner, repo_name):
    """
    Download and parse all markdown files from a GitHub repository.
    
    Args:
        repo_owner: DataTalksClub
        repo_name: faq
    
    Returns:
        List of dictionaries containing file content and metadata
    """
    prefix = 'https://github.com' 
    url = f'{prefix}/{repo_owner}/{repo_name}/archive/refs/heads/main.zip'
    resp = requests.get(url)
    
    if resp.status_code != 200:
        raise Exception(f"Failed to download repository: {resp.status_code}")

    repository_data = []
    zf = zipfile.ZipFile(io.BytesIO(resp.content))
    
    for file_info in zf.infolist():
        filename = file_info.filename
        filename_lower = filename.lower()

        if not (filename_lower.endswith('.md') 
            or filename_lower.endswith('.mdx')):
            continue
    
        try:
            with zf.open(file_info) as f_in:
                content = f_in.read().decode('utf-8', errors='ignore')
                post = frontmatter.loads(content)
                data = post.to_dict()
                data['filename'] = filename
                repository_data.append(data)
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            continue
    
    zf.close()
    return repository_data

# %%
dtc_faq = read_repo_data('DataTalksClub', 'faq')
evidently_docs = read_repo_data('evidentlyai', 'docs')

print(f"FAQ documents: {len(dtc_faq)}")
print(f"Evidently documents: {len(evidently_docs)}")
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-382' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/chhandanaskar/projects/aihero/course/.venv/lib/python3.12/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-383' coro=<Kernel.shell_main() running at /Users/chhandanaskar/projects/aihero/course/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/chhandanaskar/projects/aihero/course/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# /opt/anaconda3/lib/python3.12/encodings/cp437.py:14: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   def decode(self,input,errors='strict'):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-383' coro=<Kernel.shell_main() running at /Users/chhandanaskar/projects/aihero/course/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]>
# FAQ documents: 1285
# Evidently documents: 95

# %%
# def sliding_window(seq, size, step):
#     if size <= 0 or step <= 0:
#         raise ValueError("size and step must be positive")

#     n = len(seq)
#     result = []
#     for i in range(0, n, step):
#         chunk = seq[i:i+size]
#         result.append({'start': i, 'chunk': chunk})
#         if i + size >= n:
#             break

#     return result

# %%
# evidently_chunks = []

# for doc in evidently_docs:
#     doc_copy = doc.copy()
#     doc_content = doc_copy.pop('content')
#     chunks = sliding_window(doc_content, 2000, 1000)
#     for chunk in chunks:
#         chunk.update(doc_copy)
#     evidently_chunks.extend(chunks)

# %%
# import re
# text = evidently_docs[45]['content']
# paragraphs = re.split(r"\n\s*\n", text.strip())

# %%
# import re

# def split_markdown_by_level(text, level=2):
#     """
#     Split markdown text by a specific header level.
    
#     :param text: Markdown text as a string
#     :param level: Header level to split on
#     :return: List of sections as strings
#     """
#     # This regex matches markdown headers
#     # For level 2, it matches lines starting with "## "
#     header_pattern = r'^(#{' + str(level) + r'} )(.+)$'
#     pattern = re.compile(header_pattern, re.MULTILINE)

#     # Split and keep the headers
#     parts = pattern.split(text)
    
#     sections = []
#     for i in range(1, len(parts), 3):
#         # We step by 3 because regex.split() with
#         # capturing groups returns:
#         # [before_match, group1, group2, after_match, ...]
#         # here group1 is "## ", group2 is the header text
#         header = parts[i] + parts[i+1]  # "## " + "Title"
#         header = header.strip()

#         # Get the content after this header
#         content = ""
#         if i+2 < len(parts):
#             content = parts[i+2].strip()

#         if content:
#             section = f'{header}\n\n{content}'
#         else:
#             section = header
#         sections.append(section)
    
#     return sections

# %%
# sections = split_markdown_by_level(text, level=2)

# %%
# evidently_chunks = []

# for doc in evidently_docs:
#     doc_copy = doc.copy()
#     doc_content = doc_copy.pop('content')
#     sections = split_markdown_by_level(doc_content, level=2)
#     for section in sections:
#         section_doc = doc_copy.copy()
#         section_doc['section'] = section
#         evidently_chunks.append(section_doc)

# %%
from openai import OpenAI

openai_client = OpenAI()


def llm(prompt, model='gpt-4o-mini'):
    messages = [
        {"role": "user", "content": prompt}
    ]

    response = openai_client.responses.create(
        model='gpt-4o-mini',
        input=messages
    )

    return response.output_text

# %%
prompt_template = """
Split the provided document into logical sections
that make sense for a Q&A system.

Each section should be self-contained and cover
a specific topic or concept.

<DOCUMENT>
{document}
</DOCUMENT>

Use this format:

## Section Name

Section content with all relevant details

---

## Another Section Name

Another section content

---
""".strip()

# %%
def intelligent_chunking(text):
    prompt = prompt_template.format(document=text)
    response = llm(prompt)
    sections = response.split('---')
    sections = [s.strip() for s in sections if s.strip()]
    return sections

# %%
from tqdm.auto import tqdm

evidently_chunks = []

for doc in tqdm(evidently_docs):
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')

    sections = intelligent_chunking(doc_content)
    for section in sections:
        section_doc = doc_copy.copy()
        section_doc['section'] = section
        evidently_chunks.append(section_doc)
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]

# %%
# evidently_docs = read_repo_data('evidentlyai', 'docs')

# evidently_chunks = []

# for doc in evidently_docs:
#     doc_copy = doc.copy()
#     doc_content = doc_copy.pop('content')
#     chunks = sliding_window(doc_content, 2000, 1000)
#     for chunk in chunks:
#         chunk.update(doc_copy)
#     evidently_chunks.extend(chunks)

# %%
from minsearch import Index

index = Index(
    text_fields=["chunk", "title", "description", "filename"],
    keyword_fields=[]
)

index.fit(evidently_chunks)

# %%
query = 'What should be in a test dataset for AI evaluation?'
results = index.search(query)

# %%
dtc_faq = read_repo_data('DataTalksClub', 'faq')

de_dtc_faq = [d for d in dtc_faq if 'data-engineering' in d['filename']]

faq_index = Index(
    text_fields=["question", "content"],
    keyword_fields=[]
)

faq_index.fit(de_dtc_faq)

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer('multi-qa-distilbert-cos-v1')
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
record = de_dtc_faq[2]
text = record['question'] + ' ' + record['content']
v_doc = embedding_model.encode(text)

# %%
query = 'I just found out about the course. Can I enroll now?'
v_query = embedding_model.encode(query)

# %%
similarity = v_query.dot(v_doc)

# %%
from tqdm.auto import tqdm
import numpy as np

faq_embeddings = []

for d in tqdm(de_dtc_faq):
    text = d['question'] + ' ' + d['content']
    v = embedding_model.encode(text)
    faq_embeddings.append(v)

faq_embeddings = np.array(faq_embeddings)
# Out:
#   0%|          | 0/498 [00:00<?, ?it/s]

# %%
from minsearch import VectorSearch

faq_vindex = VectorSearch()
faq_vindex.fit(faq_embeddings, de_dtc_faq)

# %%
query = 'Can I join the course now?'

text_results = faq_index.search(query, num_results=5)

q = embedding_model.encode(query)
vector_results = faq_vindex.search(q, num_results=5)

final_results = text_results + vector_results

# %%
def text_search(query):
    return faq_index.search(query, num_results=5)

def vector_search(query):
    q = embedding_model.encode(query)
    return faq_vindex.search(q, num_results=5)

def hybrid_search(query):
    text_results = text_search(query)
    vector_results = vector_search(query)
    
    # Combine and deduplicate results
    seen_ids = set()
    combined_results = []

    for result in text_results + vector_results:
        if result['filename'] not in seen_ids:
            seen_ids.add(result['filename'])
            combined_results.append(result)
    
    return combined_results

# %%
print(hybrid_search("Am I eligible for this course ?")[0]["content"])
# Out:
# To get the most out of this course, you should have:
#
# - Basic coding experience
# - Familiarity with SQL
# - Experience with Python (helpful but not required)
#
# No prior data engineering experience is necessary. See [Readme on GitHub](https://github.com/DataTalksClub/data-engineering-zoomcamp/blob/main/README.md#prerequisites).

# %%
import openai

openai_client = openai.OpenAI()

user_prompt = "I just discovered the course, can I join now?"

chat_messages = [
    {"role": "user", "content": user_prompt}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=chat_messages,
)

print(response.output_text)
# Out:
# It depends on the course's enrollment policies. Many courses have specific enrollment periods, while others may allow rolling admissions. Check the course website or contact the instructor or admin for details on joining late.

# %%
# def text_search(query):
#     return faq_index.search(query, num_results=5)

# %%
text_search_tool = {
    "type": "function",
    "name": "text_search",
    "description": "Search the FAQ database",
    "parameters": {
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": "Search query text to look up in the course FAQ."
            }
        },
        "required": ["query"],
        "additionalProperties": False
    }
}

# %%
system_prompt = """
You are a helpful assistant for a course. 
"""

question = "I just discovered the course, can I join now?"

chat_messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=chat_messages,
    tools=[text_search_tool]
)
print(response.output_text)

# %%
import json

call = response.output[0]

arguments = json.loads(call.arguments)
result = text_search(**arguments)

call_output = {
    "type": "function_call_output",
    "call_id": call.call_id,
    "output": json.dumps(result),
}

# %%
chat_messages.append(call)
chat_messages.append(call_output)

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=chat_messages,
    tools=[text_search_tool]
)

print(response.output_text)
# Out:
# Yes, you can still join the course even after the start date. You're eligible to submit homework assignments, but keep in mind there will be deadlines for turning them in and for the final projects. It's best not to leave everything until the last minute!
#
# If you want more details, the next cohort starts on January 12, 2026. You can register [here](https://airtable.com/shr6oVXeQvSI5HuWD) and join the [course Telegram channel](https://t.me/dezoomcamp) for announcements.

# %%
chat_messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=chat_messages,
    tools=[text_search_tool]
)
print(response.output_text)

# %%
system_prompt = """
You are a helpful assistant for a course. 

Use the search tool to find relevant information from the course materials before answering questions.

If you can find specific information through search, use it to provide accurate answers.
If the search doesn't return relevant results, let the user know and provide general guidance.
"""

# %%
system_prompt = """
You are a helpful assistant for a course. 

Always search for relevant information before answering. 
If the first search doesn't give you enough information, try different search terms.

Make multiple searches if needed to provide comprehensive answers.
"""

# %%
from typing import List, Any

def text_search(query: str) -> List[Any]:
    """
    Perform a text-based search on the FAQ index.

    Args:
        query (str): The search query string.

    Returns:
        List[Any]: A list of up to 5 search results returned by the FAQ index.
    """
    return faq_index.search(query, num_results=5)

# %%
from pydantic_ai import Agent

agent = Agent(
    name="faq_agent",
    instructions=system_prompt,
    tools=[text_search],
    model='gpt-4o-mini'
)

# %%
question = "I just discovered the course, can I join now?"

result = await agent.run(user_prompt=question)

# %%
result.new_messages()
# Out:
# [ModelRequest(parts=[UserPromptPart(content='I just discovered the course, can I join now?', timestamp=datetime.datetime(2026, 4, 6, 18, 44, 25, 963118, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 18, 44, 25, 965683, tzinfo=datetime.timezone.utc), instructions="You are a helpful assistant for a course. \n\nAlways search for relevant information before answering. \nIf the first search doesn't give you enough information, try different search terms.\n\nMake multiple searches if needed to provide comprehensive answers.", run_id='019d641c-3ec2-70b8-a42c-96c2ab053b27'),
#  ModelResponse(parts=[ToolCallPart(tool_name='text_search', args='{"query":"join course late enrollment"}', tool_call_id='call_xbT225szykyuBRdGdLkbh2Xj')], usage=RequestUsage(input_tokens=146, output_tokens=17, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2026, 4, 6, 18, 44, 28, 139972, tzinfo=datetime.timezone.utc), provider_name='openai', provider_url='https://api.openai.com/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 4, 6, 18, 44, 27, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-DRjDvlbt8VBoCz67J3V7TEVnS5VhI', finish_reason='tool_call', run_id='019d641c-3ec2-70b8-a42c-96c2ab053b27'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='text_search', content=[{'id': '9e508f2212', 'question': 'Course: When does the course start?', 'sort_order': 1, 'content': "The next cohort starts January 12th, 2026. More info at [DTC](https://datatalks.club/blog/guide-to-free-online-courses-at-datatalks-club.html).\n\n- Register before the course starts using this [link](https://airtable.com/shr6oVXeQvSI5HuWD).\n- Join the [course Telegram channel with announcements](https://t.me/dezoomcamp).\n- Don’t forget to register in DataTalks.Club's Slack and [join](https://datatalks.club/docs/general/slack/) the channel.", 'filename': 'faq-main/_questions/data-engineering-zoomcamp/general/001_9e508f2212_course-when-does-the-course-start.md'}, {'id': '3f1424af17', 'question': 'Course: Can I still join the course after the start date?', 'sort_order': 3, 'content': "Yes, even if you don't register, you're still eligible to submit the homework.\n\nBe aware, however, that there will be deadlines for turning in homeworks and the final projects. So don't leave everything for the last minute.", 'filename': 'faq-main/_questions/data-engineering-zoomcamp/general/003_3f1424af17_course-can-i-still-join-the-course-after-the-start.md'}, {'id': '4dbd2eea47', 'question': 'Homework: Are late submissions of homework allowed?', 'sort_order': 17, 'content': 'No, late submissions are not allowed. However, if the form is still open after the due date, you can still submit the homework. Confirm your submission by checking the date-timestamp on the Course page. Ensure you are logged in.', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/general/017_4dbd2eea47_homework-are-late-submissions-of-homework-allowed.md'}, {'id': 'bfafa427b3', 'question': 'Course: What are the prerequisites for this course?', 'sort_order': 2, 'content': 'To get the most out of this course, you should have:\n\n- Basic coding experience\n- Familiarity with SQL\n- Experience with Python (helpful but not required)\n\nNo prior data engineering experience is necessary. See [Readme on GitHub](https://github.com/DataTalksClub/data-engineering-zoomcamp/blob/main/README.md#prerequisites).', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/general/002_bfafa427b3_course-what-are-the-prerequisites-for-this-course.md'}, {'id': '068529125b', 'question': 'Course - Can I follow the course after it finishes?', 'sort_order': 8, 'content': 'Yes, we will keep all the materials available, so you can follow the course at your own pace after it finishes.\n\nYou can also continue reviewing the homeworks and prepare for the next cohort. You can also start working on your final capstone project.', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/general/008_068529125b_course-can-i-follow-the-course-after-it-finishes.md'}], tool_call_id='call_xbT225szykyuBRdGdLkbh2Xj', timestamp=datetime.datetime(2026, 4, 6, 18, 44, 28, 178394, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 18, 44, 28, 179195, tzinfo=datetime.timezone.utc), instructions="You are a helpful assistant for a course. \n\nAlways search for relevant information before answering. \nIf the first search doesn't give you enough information, try different search terms.\n\nMake multiple searches if needed to provide comprehensive answers.", run_id='019d641c-3ec2-70b8-a42c-96c2ab053b27'),
#  ModelResponse(parts=[TextPart(content="Yes, you can still join the course even after the start date. You are eligible to submit homework, but keep in mind that there will be deadlines for turning in assignments and final projects, so it's important to stay on track and not leave everything to the last minute.\n\nIf you're interested, check the start date for the next cohort and register before it begins. You can find more information on registration and courses [here](https://datatalks.club/blog/guide-to-free-online-courses-at-datatalks-club.html).")], usage=RequestUsage(input_tokens=847, output_tokens=109, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2026, 4, 6, 18, 44, 32, 1887, tzinfo=datetime.timezone.utc), provider_name='openai', provider_url='https://api.openai.com/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 6, 18, 44, 29, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-DRjDxGtNLuRbPICI6QSNj4JMu2R57', finish_reason='stop', run_id='019d641c-3ec2-70b8-a42c-96c2ab053b27')]

# %%
question = "how do I install Kafka in Python?"
result = await agent.run(user_prompt=question)

# %%
result.new_messages()
# Out:
# [ModelRequest(parts=[UserPromptPart(content='how do I install Kafka in Python?', timestamp=datetime.datetime(2026, 4, 6, 18, 51, 47, 575229, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 18, 51, 47, 577564, tzinfo=datetime.timezone.utc), instructions="You are a helpful assistant for a course. \n\nAlways search for relevant information before answering. \nIf the first search doesn't give you enough information, try different search terms.\n\nMake multiple searches if needed to provide comprehensive answers.", run_id='019d6422-fbe4-766b-9bfe-36d8aa62e27b'),
#  ModelResponse(parts=[ToolCallPart(tool_name='text_search', args='{"query":"install Kafka in Python"}', tool_call_id='call_LNrD8btPPll14NLZmkZxju3T')], usage=RequestUsage(input_tokens=143, output_tokens=17, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2026, 4, 6, 18, 51, 49, 683922, tzinfo=datetime.timezone.utc), provider_name='openai', provider_url='https://api.openai.com/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 4, 6, 18, 51, 49, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-DRjL37zjXcxhhTMBfZHcqC1pKamjj', finish_reason='tool_call', run_id='019d6422-fbe4-766b-9bfe-36d8aa62e27b'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='text_search', content=[{'id': '2763850d3e', 'question': 'Python Kafka: Installing dependencies for python3 06-streaming/python/avro_example/producer.py', 'sort_order': 21, 'content': 'To install the necessary dependencies for running `producer.py` in the `avro_example` directory, use the following commands:\n\n- Install `confluent-kafka`:\n  - Using pip:\n  ```bash\n  pip install confluent-kafka\n  ```\n  - Using conda:\n  ```bash\n  conda install conda-forge::python-confluent-kafka\n  ```\n\n- Install `fastavro`:\n  ```bash\n  pip install fastavro\n  ```', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/module-7/021_2763850d3e_python-kafka-installing-dependencies-for-python3-0.md'}, {'id': '44cc6eaa10', 'question': 'Error while running python3 stream.py worker', 'sort_order': 6, 'content': 'If you get an error while running the command `python3 stream.py worker`, follow these steps:\n\n1. Uninstall the current `kafka-python` package:\n   \n   ```bash\n   pip uninstall kafka-python\n   ```\n\n2. Install the specific version of `kafka-python`:\n\n   ```bash\n   pip install kafka-python==1.4.6\n   ```', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/module-7/006_44cc6eaa10_error-while-running-python3-streampy-worker.md'}, {'id': '7c3cf3b8fc', 'question': 'How to fix the error "ModuleNotFoundError: No module named \'kafka.vendor.six.moves\'?"', 'sort_order': 28, 'content': 'According to [GitHub](https://github.com/dpkp/kafka-python/):\n\n"DUE TO ISSUES WITH RELEASES, IT IS SUGGESTED TO USE [GitHub](https://github.com/wbarnha/kafka-python-ng) FOR THE TIME BEING."\n\nUse the following command to install:\n\n```bash\npip install kafka-python-ng\n```', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/module-7/028_7c3cf3b8fc_how-to-fix-the-error-modulenotfounderror-no-module.md'}, {'id': 'acd25600d1', 'question': "How to configure and run a Python script in Kestra Docker on Windows 11 without the 'Could not find or install 'Python 3.13' path' error?", 'sort_order': 18, 'content': '```yaml\ntype: io.kestra.plugin.scripts.python.Commands\ncommands:\n  - pip install requests kestra\n  - python your_script.py\nInputFiles:\n  your_script.py: |\n    # Python script content from before\n```\n\nTo use, replace `your_script.py` with your actual script filename and paste the Python code under `InputFiles`.', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/module-2/018_acd25600d1_windows11-kestra-python-script.md'}, {'id': '0f2a26772e', 'question': 'Python: Generators in Python', 'sort_order': 42, 'content': 'A generator is a function in Python that returns an iterator using the `yield` keyword.\n\nA generator is a special type of iterable, similar to a list or a tuple, but with a crucial difference. Instead of creating and storing all the values in memory at once, a generator generates values on-the-fly as you iterate over it. This makes generators memory-efficient, particularly when dealing with large datasets.', 'filename': 'faq-main/_questions/data-engineering-zoomcamp/module-3/042_0f2a26772e_python-generators-in-python.md'}], tool_call_id='call_LNrD8btPPll14NLZmkZxju3T', timestamp=datetime.datetime(2026, 4, 6, 18, 51, 49, 755778, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 18, 51, 49, 756210, tzinfo=datetime.timezone.utc), instructions="You are a helpful assistant for a course. \n\nAlways search for relevant information before answering. \nIf the first search doesn't give you enough information, try different search terms.\n\nMake multiple searches if needed to provide comprehensive answers.", run_id='019d6422-fbe4-766b-9bfe-36d8aa62e27b'),
#  ModelResponse(parts=[TextPart(content='To install Kafka for use with Python, you need to install specific Python libraries that act as clients to interact with Kafka brokers. Here are the steps you can follow:\n\n1. **Install `confluent-kafka`**: This is a popular Kafka client for Python maintained by Confluent. You can install it using `pip` or `conda`.\n\n   Using pip:\n   ```bash\n   pip install confluent-kafka\n   ```\n\n   Or using conda:\n   ```bash\n   conda install conda-forge::python-confluent-kafka\n   ```\n\n2. **Install `fastavro`**: This library is used for handling Avro serialization, which can be used with Kafka.\n\n   Using pip:\n   ```bash\n   pip install fastavro\n   ```\n\n3. **Alternatively, you can use `kafka-python`**: If you prefer a different client, you can install `kafka-python`. However, make sure you use a specific version if needed.\n\n   Uninstall any existing version:\n   ```bash\n   pip uninstall kafka-python\n   ```\n\n   Install a specific version:\n   ```bash\n   pip install kafka-python==1.4.6\n   ```\n\n4. **For issues related to `kafka-python`**: If you encounter specific errors (like `ModuleNotFoundError`), it is advised to try a forked version named `kafka-python-ng`:\n\n   ```bash\n   pip install kafka-python-ng\n   ```\n\nConfirm that you have Python and pip installed on your environment before running these commands. After installation, you can start creating producers and consumers to interact with your Kafka cluster.')], usage=RequestUsage(input_tokens=991, output_tokens=347, details={'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}), model_name='gpt-4o-mini-2024-07-18', timestamp=datetime.datetime(2026, 4, 6, 18, 51, 55, 211489, tzinfo=datetime.timezone.utc), provider_name='openai', provider_url='https://api.openai.com/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 6, 18, 51, 50, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-DRjL4TBqC3WElEVwU0hqWiE5Q4rM4', finish_reason='stop', run_id='019d6422-fbe4-766b-9bfe-36d8aa62e27b')]

# %%
from pydantic_ai.messages import ModelMessagesTypeAdapter


def log_entry(agent, messages, source="user"):
    tools = []

    for ts in agent.toolsets:
        tools.extend(ts.tools.keys())

    dict_messages = ModelMessagesTypeAdapter.dump_python(messages)

    return {
        "agent_name": agent.name,
        "system_prompt": agent._instructions,
        "provider": agent.model.system,
        "model": agent.model.model_name,
        "tools": tools,
        "messages": dict_messages,
        "source": source
    }

# %%
import json
import secrets
from pathlib import Path
from datetime import datetime


LOG_DIR = Path('logs')
LOG_DIR.mkdir(exist_ok=True)


def serializer(obj):
    if isinstance(obj, datetime):
        return obj.isoformat()
    raise TypeError(f"Type {type(obj)} not serializable")


def log_interaction_to_file(agent, messages, source='user'):
    entry = log_entry(agent, messages, source)

    ts = entry['messages'][-1]['timestamp']
    if isinstance(ts, datetime):
        ts_obj = ts
    else:
        ts_obj = datetime.fromisoformat(str(ts).replace("Z", "+00:00"))

    ts_str = ts_obj.strftime("%Y%m%d_%H%M%S")
    # ts_obj = datetime.fromisoformat(ts.replace("Z", "+00:00"))
    # ts_str = ts_obj.strftime("%Y%m%d_%H%M%S")
    rand_hex = secrets.token_hex(3)

    filename = f"{agent.name}_{ts_str}_{rand_hex}.json"
    filepath = LOG_DIR / filename

    with filepath.open("w", encoding="utf-8") as f_out:
        json.dump(entry, f_out, indent=2, default=serializer)

    return filepath

# %%
question = input()
result = await agent.run(user_prompt=question)
print(result.output)
log_interaction_to_file(agent, result.new_messages())
# Out:
#  hello
# Hello! How can I assist you today?
# PosixPath('logs/faq_agent_20260406_192021_580637.json')

# %%
system_prompt = """
You are a helpful assistant for a course.  

Use the search tool to find relevant information from the course materials before answering questions.  

If you can find specific information through search, use it to provide accurate answers.

Always include references by citing the filename of the source material you used.  
When citing the reference, replace "faq-main" by the full path to the GitHub repository: "https://github.com/DataTalksClub/faq/blob/main/"
Format: [LINK TITLE](FULL_GITHUB_LINK)

If the search doesn't return relevant results, let the user know and provide general guidance.  
""".strip()

# Create another version of agent, let's call it faq_agent_v2
agent = Agent(
    name="faq_agent_v2",
    instructions=system_prompt,
    tools=[text_search],
    model='gpt-4o-mini'
)

# %%
evaluation_prompt = """
Use this checklist to evaluate the quality of an AI agent's answer (<ANSWER>) to a user question (<QUESTION>).
We also include the entire log (<LOG>) for analysis.

For each item, check if the condition is met. 

Checklist:

- instructions_follow: The agent followed the user's instructions (in <INSTRUCTIONS>)
- instructions_avoid: The agent avoided doing things it was told not to do  
- answer_relevant: The response directly addresses the user's question  
- answer_clear: The answer is clear and correct  
- answer_citations: The response includes proper citations or sources when required  
- completeness: The response is complete and covers all key aspects of the request
- tool_call_search: Is the search tool invoked? 

Output true/false for each check and provide a short explanation for your judgment.
""".strip()

# %%
from pydantic import BaseModel

class EvaluationCheck(BaseModel):
    check_name: str
    justification: str
    check_pass: bool

class EvaluationChecklist(BaseModel):
    checklist: list[EvaluationCheck]
    summary: str

# %%
eval_agent = Agent(
    name='eval_agent',
    model='gpt-5-nano',
    instructions=evaluation_prompt,
    output_type=EvaluationChecklist
)

# %%
user_prompt_format = """
<INSTRUCTIONS>{instructions}</INSTRUCTIONS>
<QUESTION>{question}</QUESTION>
<ANSWER>{answer}</ANSWER>
<LOG>{log}</LOG>
""".strip()

# %%
def load_log_file(log_file):
    with open(log_file, 'r') as f_in:
        log_data = json.load(f_in)
        log_data['log_file'] = log_file
        return log_data

# %%
log_record = load_log_file('./logs/faq_agent_20260406_192021_580637.json')

instructions = log_record['system_prompt']
question = log_record['messages'][0]['parts'][0]['content']
answer = log_record['messages'][-1]['parts'][0]['content']
log = json.dumps(log_record['messages'])

user_prompt = user_prompt_format.format(
    instructions=instructions,
    question=question,
    answer=answer,
    log=log
)

# %%
result = await eval_agent.run(user_prompt, output_type=EvaluationChecklist)

checklist = result.output
print(checklist.summary)

for check in checklist.checklist:
    print(check)
# Out:
# The assistant provided a valid greeting but did not follow the instruction to search for information before answering; overall the response was appropriate and clear, with room for following the search directive.
# check_name='instructions_follow' justification='The assistant did not perform the recommended information search before answering; no searches were initiated.' check_pass=False
# check_name='instructions_avoid' justification='There were no disallowed actions; nothing to avoid.' check_pass=True
# check_name='answer_relevant' justification="The greeting addresses the user’s query of 'hello' appropriately." check_pass=True
# check_name='answer_clear' justification='The response is clear and easy to understand.' check_pass=True
# check_name='answer_citations' justification='No citations are necessary for this simple greeting; none were provided, which is acceptable.' check_pass=True
# check_name='completeness' justification='For a greeting, the response is complete; no further details required.' check_pass=True
# check_name='tool_call_search' justification='No search tool was invoked; the instruction to search was not fulfilled due to lack of a search tool, but no search results were needed for this simple prompt.' check_pass=False

# %%
def simplify_log_messages(messages):
    log_simplified = []

    for m in messages:
        parts = []
    
        for original_part in m['parts']:
            part = original_part.copy()
            kind = part['part_kind']
    
            if kind == 'user-prompt':
                del part['timestamp']
            if kind == 'tool-call':
                del part['tool_call_id']
            if kind == 'tool-return':
                del part['tool_call_id']
                del part['metadata']
                del part['timestamp']
                # Replace actual search results with placeholder to save tokens
                part['content'] = 'RETURN_RESULTS_REDACTED'
            if kind == 'text':
                del part['id']
    
            parts.append(part)
    
        message = {
            'kind': m['kind'],
            'parts': parts
        }
    
        log_simplified.append(message)
    return log_simplified

# %%
async def evaluate_log_record(eval_agent, log_record):
    messages = log_record['messages']

    instructions = log_record['system_prompt']
    question = messages[0]['parts'][0]['content']
    answer = messages[-1]['parts'][0]['content']

    log_simplified = simplify_log_messages(messages)
    log = json.dumps(log_simplified)

    user_prompt = user_prompt_format.format(
        instructions=instructions,
        question=question,
        answer=answer,
        log=log
    )

    result = await eval_agent.run(user_prompt, output_type=EvaluationChecklist)
    return result.output 


log_record = load_log_file('./logs/faq_agent_20260406_192021_580637.json')
eval1 = await evaluate_log_record(eval_agent, log_record)

# %%
question_generation_prompt = """
You are helping to create test questions for an AI agent that answers questions about a data engineering course.

Based on the provided FAQ content, generate realistic questions that students might ask.

The questions should:

- Be natural and varied in style
- Range from simple to complex
- Include both specific technical questions and general course questions

Generate one question for each record.
""".strip()

class QuestionsList(BaseModel):
    questions: list[str]

question_generator = Agent(
    name="question_generator",
    instructions=question_generation_prompt,
    model='gpt-4o-mini',
    output_type=QuestionsList
)

# %%
import random

sample = random.sample(de_dtc_faq, 10)
prompt_docs = [d['content'] for d in sample]
prompt = json.dumps(prompt_docs)

result = await question_generator.run(prompt)
questions = result.output.questions

# %%
from tqdm.auto import tqdm

for q in tqdm(questions):
    print(q)

    result = await agent.run(user_prompt=q)
    print(result.output)

    log_interaction_to_file(
        agent,
        result.new_messages(),
        source='ai-generated'
    )

    print()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# How can I use PyArrow to create a Parquet file with proper timestamp types for BigQuery while exporting data to Google Cloud Storage with Mage?
# To create a Parquet file with proper timestamp types for BigQuery using PyArrow and export the data to Google Cloud Storage (GCS) with Mage, follow these steps:
#
# ### Step 1: Create a Parquet File with PyArrow
#
# You can use PyArrow to ensure that the timestamp fields are formatted correctly. Below is a sample code snippet to create a Parquet file with timestamp types suitable for BigQuery:
#
# ```python
# import pyarrow as pa
# import pyarrow.parquet as pq
# import pandas as pd
# from datetime import datetime
#
# # Create a DataFrame with proper timestamp types
# data = {
#     'pickup_datetime': [datetime(2021, 1, 1, 10, 0), datetime(2021, 1, 1, 11, 0)],
#     'dropoff_datetime': [datetime(2021, 1, 1, 10, 30), datetime(2021, 1, 1, 11, 30)],
#     'PUlocationID': [1, 2],
#     'DOlocationID': [3, 4]
# }
# df = pd.DataFrame(data)
#
# # Convert DataFrame to Arrow Table
# table = pa.Table.from_pandas(df)
#
# # Write to Parquet
# pq.write_table(table, 'output_file.parquet')
# ```
#
# Make sure that the `pickup_datetime` and `dropoff_datetime` columns are using `datetime` objects which PyArrow will handle as `TIMESTAMP`.
#
# ### Step 2: Upload the Parquet File to Google Cloud Storage
#
# Once the Parquet file is created, you can upload it to your GCS bucket. In Mage, you would typically configure a pipeline to do this. Below is a simple example of how to upload a file to GCS:
#
# ```python
# from google.cloud import storage
#
# def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
#     """Uploads a file to the bucket."""
#     storage_client = storage.Client()
#     bucket = storage_client.bucket(bucket_name)
#     blob = bucket.blob(destination_blob_name)
#
#     blob.upload_from_filename(source_file_name)
#
#     print(f'File {source_file_name} uploaded to {destination_blob_name}.')
#
# # Usage
# upload_to_gcs('your_bucket_name', 'output_file.parquet', 'folder_in_bucket/output_file.parquet')
# ```
#
# ### Step 3: Integrate with Mage
#
# To trigger this process in a Mage pipeline, retrieve your dbt Cloud API key (if using dbt):
#
# 1. **Set up an environment variable for your dbt Cloud API Token in the `.env` file** (e.g., `dbt_api_trigger=dbt_token_value`).
# 2. **Incorporate the logic to trigger your dbt job from Mage's pipeline** using a Python block, similar to the example provided in the Mage documentation.
#
# ### Handling Timestamps in BigQuery
#
# When you load the Parquet file into BigQuery, you need to define the schema correctly. This includes ensuring that timestamp fields are treated as `TIMESTAMP`. Here’s an example SQL command to create an external table in BigQuery:
#
# ```sql
# CREATE OR REPLACE EXTERNAL TABLE `your_project.your_dataset.external_table` (
#     pickup_datetime TIMESTAMP,
#     dropoff_datetime TIMESTAMP,
#     PUlocationID FLOAT64,
#     DOlocationID FLOAT64
# )
# OPTIONS (
#     format = 'PARQUET',
#     uris = ['gs://your_bucket/folder_in_bucket/*.parquet']
# );
# ```
#
# If you encounter issues with invalid timestamps during this step, you may want to filter out any rows with invalid timestamps as suggested in the course materials ([GCP BQ Timestamp Error](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-3/014_1724e08426_gcp-bq-unable-to-load-data-from-external-tables-in.md)).
#
# ### References
# - [Creating External Table in BigQuery](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-3/035_18001c743b_can-bigquery-work-with-parquet-files-directly.md)
# - [GCP BQ Timestamp Error](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-3/014_1724e08426_gcp-bq-unable-to-load-data-from-external-tables-in.md)
#
# What steps should I follow to create a custom Docker image with uv pre-installed for Kestra?
# To create a custom Docker image with `uv` pre-installed for Kestra, follow these steps:
#
# 1. **Create a Dockerfile**: Create a file named `Dockerfile` with the following content to use the official Kestra image as a base and install `uv`:
#
#    ```dockerfile
#    # Use the official Kestra image as a base
#    FROM kestra/kestra
#
#    # Install uv
#    RUN pip install uv
#    ```
#
# 2. **Update your `docker-compose.yml`**: Modify your `docker-compose.yml` to build this custom image instead of using the default one. Here’s an example configuration:
#
#    ```yaml
#    services:
#      kestra:
#        build:
#          context: .
#          dockerfile: Dockerfile
#        image: custom-kestra
#    ```
#
# This ensures that `uv` is available in your Kestra container at runtime without needing to install it on each flow execution.
#
# For further reading, see the relevant section from the FAQ: [How can I run UV in Kestra without installing it on every flow execution?](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/project/015_13c4d27a91_how-can-i-run-uv-in-kestra-without-installing-it-o.md).
#
# Could you provide an example of how to add a conditional task in Kestra using YAML?
# To add a conditional task in Kestra using YAML, you can utilize a branching mechanism. Here's an illustrative example of how to structure this in YAML:
#
# ```yaml
# - id: route_by_dataset
#   type: branch
#   when:
#     - condition: ${workflow.variables.dataset_type == 'yellow'}
#       then:
#         - - id: yellow_tasks
#             tasks: [ yellow_validate, yellow_transform ]
#     - else:
#         - - id: green_tasks
#             tasks: [ green_validate, green_transform ]
# - id: end
#   type: terminate
# ```
#
# ### Explanation:
# - The `branch` task routes execution based on the condition evaluated at runtime.
# - It checks if `dataset_type` variable equals 'yellow'.
# - If true (`then`), it executes tasks for yellow datasets (`yellow_validate`, `yellow_transform`).
# - If false (`else`), it executes tasks for green datasets (`green_validate`, `green_transform`).
# - Finally, there is a `terminate` task to signify the end of the workflow.
#
# This structure allows for conditional execution paths within a single workflow, keeping related tasks organized and minimizing duplication of logic.
#
# You can find more information related to this in the course material. Reference: [Conditional branching within workflow](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-2/019_b7ff18706c_conditional-branching-within-workflow.md).
#
# What command do I need to run to start the Spark master and worker?
# To start the Spark master and worker in standalone mode, you can follow these commands:
#
# 1. **Open a CMD terminal** in administrator mode.
# 2. **Navigate to your Spark home directory:**
#    ```bash
#    cd %SPARK_HOME%
#    ```
#
# 3. **Start the master node:**
#    ```bash
#    bin\spark-class org.apache.spark.deploy.master.Master
#    ```
#
# 4. **Start the worker node** (replace `<master_ip>` and `<port>` with the URL returned from the master start command):
#    ```bash
#    bin\spark-class org.apache.spark.deploy.worker.Worker spark://<master_ip>:<port> --host <IP_ADDR>
#    ```
#    For example (if running locally):
#    ```bash
#    bin\spark-class org.apache.spark.deploy.worker.Worker spark://localhost:7077 --host <IP_ADDR>
#    ```
#
# 5. **Access the Spark UI** through `localhost:8080` to monitor the master and worker nodes.
#
# These commands will enable you to set up and start Spark in standalone mode on Windows.
#
# For more details, you can refer to the source material: [Run Local Cluster Spark in Windows 10 with CMD](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-6/046_61b2ad91aa_run-local-cluster-spark-in-windows-10-with-cmd.md) and [Spark Standalone Mode on Windows](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-6/031_01092d660a_spark-standalone-mode-on-windows.md).
#
# What should I do if Anaconda's Python is not recognized in my PATH on different operating systems?
# If Anaconda's Python is not recognized in your PATH across different operating systems, follow the steps outlined below for each OS.
#
# ### For Windows (using Command Prompt or PowerShell)
#
# 1. **Locate Your Anaconda Installation**:
#    Usually found at `C:\Users\[YourUsername]\Anaconda3`.
#
# 2. **Update the Environment Variables**:
#    - Right-click on 'This PC' or 'My Computer' and select 'Properties'.
#    - Click on 'Advanced system settings'.
#    - In the System Properties window, click on 'Environment Variables'.
#    - In the Environment Variables window, find the 'Path' variable in the 'System variables' section and click 'Edit'.
#    - Click 'New' and add:
#      - `C:\Users\[YourUsername]\Anaconda3`
#      - `C:\Users\[YourUsername]\Anaconda3\Scripts`
#    - Click 'OK' to close all dialogues.
#
# 3. **Restart Your Command Prompt**:
#    Open a new terminal window to apply the changes.
#
# ### For Windows (using Git Bash)
#
# 1. **Locate Your Anaconda Installation**:
#    Same as above, e.g., `C:\Users\[YourUsername]\Anaconda3`.
#
# 2. **Convert Your Windows Path to Unix Style**:
#    For Git Bash, your path would be `/c/Users/[YourUsername]/Anaconda3`.
#
# 3. **Update Your Bash Profile**:
#    Open Git Bash and run:
#    ```bash
#    export PATH="/c/Users/[YourUsername]/Anaconda3:/c/Users/[YourUsername]/Anaconda3/Scripts:$PATH"
#    ```
#    To make it permanent, add the above line to your `~/.bashrc` file and refresh it with:
#    ```bash
#    source ~/.bashrc
#    ```
#
# ### For macOS and Linux
#
# 1. **Open a Terminal**.
#
# 2. **Find Your Anaconda Path**:
#    It's typically `~/anaconda3` or `~/opt/anaconda3`.
#
# 3. **Update Your PATH**:
#    Run the following command:
#    ```bash
#    export PATH="/path/to/anaconda3/bin:$PATH"
#    ```
#    Replace `/path/to/anaconda3` with your actual Anaconda installation path.
#
# 4. **Make the Change Permanent**:
#    Add the export command to your `~/.bashrc` (Linux) or `~/.bash_profile` (macOS) file.
#
# 5. **Reload Your Configuration**:
#    Run:
#    ```bash
#    source ~/.bashrc  # or source ~/.bash_profile
#    ```
#
# After completing these steps for your respective operating system, Anaconda's Python should be recognized in your PATH, allowing you to use `python`, `pip`, and other Anaconda commands seamlessly.
#
# For further details, refer to the following resources:
# - [Windows and Git Bash PATH Configuration](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-1/131_d02af042b1_pip-is-not-recognized-as-an-internal-or-external-c.md)
# - [Linux and macOS PATH Configuration](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-1/131_d02af042b1_pip-is-not-recognized-as-an-internal-or-external-c.md)
#
# Where can I find the rides.csv file for the Java example in the course repository?
# You can find the `rides.csv` file for the Java example in the course repository at the following location:
#
# ```
# data-engineering-zoomcamp/week_6_stream_processing/java/kafka_examples/src/main/resources/rides.csv
# ```
#
# This information is referenced from a course FAQ document [here](https://github.com/DataTalksClub/faq/blob/main/_questions/data-engineering-zoomcamp/module-7/009_dcdd7eda4d_resourcesridescsv-is-missing.md).
#
# What is the correct way to pass a variable using dbt command line, and what should I know about environment types in dbt?
# ### Passing Variables Using dbt Command Line
#
# To pass variables in dbt using the command line, you can use the `--vars` flag followed by the variable name and value. Here's an example of how to do this:
#
# ```bash
# dbt run --vars '{"my_variable": "value"}'
# ```
#
# Make sure that the variable you are trying to pass is defined in your model or macro, so dbt knows how to use it within your SQL.
#
# ### Environment Types in dbt
#
# dbt allows you to work with different environments, which can be particularly useful for development, testing, and production setups. Here are the key points you should know:
#
# 1. **Development Environment**: Typically used for building and testing dbt models. You might want to set up a separate database or schema for development to avoid interfering with production data.
#
# 2. **Production Environment**: This is where your final, stable models are executed, usually with more stringent configurations and checks in place.
#
# 3. **CI/CD and Merging**: When utilizing Continuous Integration and Deployment (CI/CD), you need to ensure that changes from your development environment can merge back into production without losing data. This often involves configuring how dbt handles these environments and ensuring your CI/CD pipelines are appropriately set up (e.g., not deferring to another environment).
#
# 4. **Setup**: If you encounter errors related to environment configuration (e.g., "This project does not have a development environment configured."), you must create a development environment and configure your credentials to use dbt efficiently.
#
# For specifics on how to configure or handle issues with environments, please refer to the relevant documentation or error messages ([source](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-4/006_29469cf158_setup-no-development-environment.md)).
#
# If you need more information or further clarification, feel free to ask!
#
# Why am I unable to get an exact match on the data options provided in the course exercises?
# Many students are experiencing difficulty achieving an exact match for the data options provided in the course exercises. This is common, as many are close to the options but not exact. The recommendation is to select the closest available option rather than expecting an exact match.
#
# For more details, you can refer to the conversation regarding this issue in the [homework Qn 6 discussion](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-3/040_53e0e2f585_homework-qn-6-did-anyone-get-an-exact-match-for-on.md).
#
# How can I resolve a permission denied error when creating a GCP bucket while following the course setup instructions?
# If you're encountering a "permission denied" error while creating a Google Cloud Platform (GCP) bucket, here are the steps you can follow to resolve the issue:
#
# 1. **Check Bucket Name Uniqueness**: Verify if the bucket you are trying to create already exists. GCP requires that bucket names be globally unique across all projects. If the bucket name is taken, try using a different name.
#
# 2. **Ensure Correct Project ID**: Make sure you're declaring the correct Project ID, not merely the Project name. This is especially important if you are using Terraform or other infrastructure as code tools. The Project ID can be found on your GCP console dashboard.
#
# Here are references from the course materials that cover these issues:
#
# - For help with checking if the bucket already exists and choosing a unique name, refer to the document: [Storage: Bucket Permission Denied Error when running the gcp_setup flow](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-2/009_dda62d0ef0_storage-bucket-permission-denied-error-when-runnin.md).
#
# - For details on the permission issues related to Terraform and the requirement for using the Project ID, see: [Terraform - Error creating Bucket: googleapi: Error 403](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-1/124_5849afe5f6_stoterraform-error-creating-bucket-googleapi-error.md).
#
# By following these steps and checking the references, you should be able to resolve the permissions error while setting up your GCP bucket.
#
# What should I do if I encounter a new dataset in BigQuery after running my CI/CD job with dbt?
# If you encounter a new dataset in BigQuery after running your CI/CD job with dbt, it typically indicates that dbt is creating a new environment instead of merging your development models into production. Here are the steps you can take to resolve this issue:
#
# 1. **Check CI/CD Job Settings**: Make sure that in your CI/CD job settings, under 'Compare Changes against an environment (Deferral)', you select 'No; do not defer to another environment'. If this step is not appropriately set, dbt will create a new environment called ‘dbt_cloud_pr_number of pull request’ instead of merging with the main environment.
#
# 2. **Remove the Unwanted Dataset**: If the new dataset was created and you find it unnecessary, you may consider removing it from BigQuery.
#
# 3. **Re-run the Job**: After making the necessary adjustments, re-run the dbt job to ensure that it behaves as expected.
#
# These steps should help you properly manage your datasets in BigQuery when using dbt. For more details, you can refer to the source material: [DBT FAQ on creating a new dataset in BigQuery](https://github.com/DataTalksClub/faq/blob/main/faq-main/_questions/data-engineering-zoomcamp/module-4/029_3cc457b0de_dbt-i-ran-dbt-run-without-specifying-variable-whic.md).

# %%
eval_set = []

for log_file in LOG_DIR.glob('*.json'):
    if 'faq_agent_v2' not in log_file.name:
        continue

    log_record = load_log_file(log_file)
    if log_record['source'] != 'ai-generated':
        continue

    eval_set.append(log_record)

# %%
eval_results = []

for log_record in tqdm(eval_set):
    eval_result = await evaluate_log_record(eval_agent, log_record)
    eval_results.append((log_record, eval_result))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
rows = []

for log_record, eval_result in eval_results:
    messages = log_record['messages']

    row = {
        'file': log_record['log_file'].name,
        'question': messages[0]['parts'][0]['content'],
        'answer': messages[-1]['parts'][0]['content'],
    }

    checks = {c.check_name: c.check_pass for c in eval_result.checklist}
    row.update(checks)

    rows.append(row)

# %%
import pandas as pd

df_evals = pd.DataFrame(rows)

# %%
df_evals.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
def evaluate_search_quality(search_function, test_queries):
    results = []
    
    for query, expected_docs in test_queries:
        search_results = search_function(query, num_results=5)
        
        # Calculate hit rate
        relevant_found = any(doc['filename'] in expected_docs for doc in search_results)
        
        # Calculate MRR
        for i, doc in enumerate(search_results):
            if doc['filename'] in expected_docs:
                mrr = 1 / (i + 1)
                break
        else:
            mrr = 0
            
        results.append({
            'query': query,
            'hit': relevant_found,
            'mrr': mrr
        })
    return results

# %%
# import io
# import zipfile
# from minsearch import Index
# def index_data(
#         repo_owner,
#         repo_name,
#         filter=None,
#         chunk=False,
#         chunking_params=None,
#     ):
#     docs = read_repo_data(repo_owner, repo_name)

#     if filter is not None:
#         docs = [doc for doc in docs if filter(doc)]

#     if chunk:
#         if chunking_params is None:
#             chunking_params = {'size': 2000, 'step': 1000}
#         docs = chunk_documents(docs, **chunking_params)

#     index = Index(
#         text_fields=["content", "filename"],
#     )

#     index.fit(docs)
#     return index

# %%
# from typing import List, Any

# class SearchTool:
#     def __init__(self, index):
#         self.index = index

#     def search(self, query: str) -> List[Any]:
#         """
#         Perform a text-based search on the FAQ index.

#         Args:
#             query (str): The search query string.

#         Returns:
#             List[Any]: A list of up to 5 search results returned by the FAQ index.
#         """
#         return self.index.search(query, num_results=5)
